# %% [markdown]
# ## Data Science Project on Employee Performance Analysis
# #### Business Case:
# We must analyze the feautres present in the dataset, establish a correlation between the feautres and employee performance, and forecast the employee performance rating based on the feautres.

# %% [markdown]
# ### VISUALIZATION SUMMARY:
#
# 1. Domain Analysis Of all features
# 2. Univariate Analysis with insights
# 3. Bivariate Analysis with insights
# 4. Multivariat Analysis with insights

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')  # setting up background
from scipy import stats

# TO avoid warnings
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data

# %%
data = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')
pd.set_option('display.max_columns',None) # Used to display the all features
data.head() # Get first 5 rows
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %% [markdown]
# ### Domain Analysis
#
# #### We will now check the feautres present in the dataset

# %% [markdown]
# 1.EmpNumber:
# An employee ID, also known as an employee number or employee code, is a special identifier that has been given to every single employee of a corporation.
#
# 2.Age:
# Employee's age in years
#
# 3.Gender:
# Employee Gender which can be either Male or Female
#
# 4.EducationBackground:
# This will be an employee's high school diploma or post-secondary degree.
#
# 5.MaritalStatus:
# The two unique categories that express a person's relationship with a significant other are their civil status or marital status.
#
# 6.EmpDepartment:
# Employee-specific department
#
# 7.EmpJobRole:
# A job role is the primary duty associated with a job profile or employment position.
#
# 8.BusinessTravelFrequency:
# the travel history of an employee for official business.
#
# 9.DistanceFromHome:
# distance between an employee's house and workplace.
#
# 10.EmpEducationLevel:
# Employee education level refers to their academic background. It might be a certificate, degree, master's degree, or PhD, for instance.
#
# 11.EmpEnvironmentSatisfaction:
# The evaluation of employees satisfaction with the environment
#
# 12.EmpHourlyRate:
# The amount paid to an employee for each hour performed is referred to as the hourly rate.
#
# 13.EmpJobInvolvement:
# The term "job involvement" describes a condition of psychological identification with one's employment, or the extent to which one's job informs their identity. It has been viewed from an organizational standpoint as the key to unlocking employee motivation and boosting productivity.
#
# 14.EmpJobLevel:
# The responsibility level and expectations are determined by job levels, often known as job grades and classifications.
#
# 15.EmpJobSatisfaction:
# the degree to which employees are happy with their jobs.
#
# 16.NumCompaniesWorked:
# How many companies did the individual work for?
#
# 17.OverTime:
# Whether an employee works overtime. [Yes, No]
#
# 18.EmpLastSalaryHikePercent:
# Salary Increase Percentage of Employed in Previous Year.
#
# 19.EmpRelationshipSatisfaction:
# Healthy connections may inspire workers and boost morale. Employees are better able to concentrate on their jobs when they put aside personal conflicts.
#
# 20.TotalWorkExperienceInYears:
# Years of experience for the employee.
#
# 21.TrainingTimesLastYear:
# Total training completed by staff members last year.
#
# 22.EmpWorkLifeBalance:
# The term "work-life balance" refers to employees finding a balance between their job and personal lives. A healthy work-life balance for employees can boost morale, boost retention rates, lower absence rates, draw in fresh talent, and lower stress levels.
#
# 23.ExperienceYearsAtThisCompany:
# Total number of years spent at the current company.
#
# 24.ExperienceYearsInCurrentRole:
# Total number of years in the work role.
#
# 25.YearsSinceLastPromotion:
# Total number of years since the employee's last promotion.
#
# 26.YearsWithCurrManager:
# Total number of employee years under the current manager.
#
# 27.Attrition:
# The natural, voluntary departure of employees from an organization is known as staff attrition. Employee attrition occurs when employees quit their jobs for: Personal reasons. motivation on the job.
#
# 28.PerformanceRating:
# This aspect, which indicates the overall evaluation of employee performance in the firm, is its goal.

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# #### PLOTS USED:
#
# #### continuous features
#
# histogram: A histogram is a bar graph-like representation of data that buckets a range of classes into columns along the horizontal x-axis. The vertical y-axis represents the number count or percentage of occurrences in the data for each column.
#
# lineplots:A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value.
#
# #### Discrete and Categorical
#
# Countplot: countplot is used to Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# #### 1.Age

# %%
plt.figure(figsize=(5,5))
sns.histplot(x='Age',data=data)
plt.xlabel('Age of Employees',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation:
#
#  - The majority of the workforce is between the ages of 25 and 40, with an age range of 18 to 60.

# %% [markdown]
# #### 2.Employee Hourly Rate

# %%
plt.figure(figsize=(5,5))
sns.histplot(x='EmpHourlyRate',data=data)
plt.xlabel('Employee Hourly Rate',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation:
# The majority of employees' hourly rates fall between the range of 30 to 100.
#
#
# #### 3.Total Work Experience In Years

# %%
plt.figure(figsize=(5,5))
sns.histplot(x='TotalWorkExperienceInYears',data=data)
plt.xlabel('Total Work Experience In Years of Employees',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation:
#
# Work experiance range between 0 to 40,Most of the employee experiance ranges between 5 to 10.
#
# #### 4. Years of Experience at this Company

# %%
plt.figure(figsize=(5,5))
sns.histplot(x='ExperienceYearsAtThisCompany',data=data)
plt.xlabel('Years of Experience At This Company',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation: The majority of employees join between 0 and 5 when the range of experience inside the same company is 0 to 40.

# %%
count = data[['Gender', 'EducationBackground', 'MaritalStatus','BusinessTravelFrequency','DistanceFromHome',
              'EmpEducationLevel', 'EmpEnvironmentSatisfaction','EmpJobInvolvement', 'EmpJobLevel',
              'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime']] # making list of next 12 feature

plt.figure(figsize=(20,25)) # defining canvas size
plotno = 1 # counter

for column in count: # iteration of columns / acessing the columns from count 
    if plotno<=13:    # set the limit
        plt.subplot(4,3,plotno) # # plotting 12 graphs (4-rows,3-columns) ,plotnumber is for count
        sns.countplot(x=count[column]) # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# #### Observation:
#
# #### 5.Gender:
# - The majority of the company's employees are men.
#
# #### 6.Education Background:
# - The majority of employees' educational backgrounds are in life sciences and medicine, and there are more than 100 with backgrounds in marketing.
# - Employees with other educational backgrounds make up less than 100.
#
# #### 7.MaritalStatus:
# - Most of the employee is married as well as less than 400 employee is single.
# - There are fewer than 300 employees that are divorced.
#
# #### 8.Business Travel Frequency:
# - Less than 220 employees frequently travel, with the maximum number of employees traveling rarely for business purposes.
# - less than 120 employees are still not traveling for business purposes.
#
# #### 9.Distance From Home:
# - The distance from home to the company can range from 1 to 29 miles.
# - The maximum distance from an employee's house to the workplace is 10 miles or less.
#
# #### 10.Educational Level:
# - There are five different educational levels in all. Maximum number of level 3 and level 4 personnel
# - Employees at the second education level are under 250, and those at the first and fifth education levels are under 150.
#
# #### 11.Employee Environment Satisfaction:
# - The majority of employees are satisfied at levels 3 and 4.
# - less than 250 employees  have rated environmental satisfaction levels 1 and 2
#
# #### 12.Employee Job Involvement:
# - Employees with job participation level 3 are more numerous than those with level 2, which number less than 300.
# - Less than 100 workers have job involvements 1 and 4.
#
# #### 13.Employee Job Level:
# - Employee job levels range from 1 to 5, with 1 and 2 being the most common levels.
# - There must be a minimum employees at job level 5, and there are less than 180 employers at levels 3 and 4.
#
# #### 14.Employee Job Satisfaction:
# - More workers than not rate their level of job satisfaction as 3 or 4.
# - Less than 250 employees have a 1 or 2 score for job satisfaction.
#
# #### 15.Number Companies Worked:
# - Maximum number of employees are employed by a single company.
# - less people are employed by more than five companies.
#
# #### 16.Overtime:
# - Less than 350 employees work overtime in the company, yet there are more employees who do so.

# %%
count2 = data[['EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction','TrainingTimesLastYear','EmpWorkLifeBalance',
               'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager', 'Attrition', 
               'PerformanceRating']]  #Making next feature list to plot the graph

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in count2: # iteration of columns / acessing the columns from count 
    if plotno<=10:    # set the limit
        plt.subplot(3,3,plotno) # # plotting 9 graphs (3-rows,3-columns) ,plotnumber is for count
        sns.countplot(x=count2[column]) # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# #### Observation:
# #### 17.Employee Last Salary Hike Percent:
# - The majority of employee wage increases fall between 11 and 14%, with a total pay rise range of 11 to 25.
# - The most recent pay raise for fewer than 80 employees ranged from 15% to 19%.
#
# #### 18.Employee Relationship Satisfaction:
# - Employee relationship satisfaction scores vary from 1 to 4.
# - More people have rated their relationship satisfaction as 3 and 4
# - whereas fewer than 250 employees have rated it as 1 and 2.
#
# #### 19.Training Times LastYear:
# - The range of training time in last year is between 0 to 6
# - Most of the employee are doing their training for 2nd & 3rd time
# - remaining all times is less than 100.
#
# #### 20.Employee Work Life Balance:
# - There are more number of employees who voted work life balance as 3 than
# - less than 300 employee voted work life balance as 2.
# - there are Minimum number of people who voted work life balance as 1
# - less than 100 employee work life balance voted as 4.
#
# #### 21.Experiance In Current Role:
# - The Employee with Maximum current role experience is 18 years.
# - Most of the employee have 2 years of experience in current role
# - Number of employee who has 7 year of experiance employee is less than 180
# - less than 200 employee have not current role experience.
#
# #### 22.Years Since Last Promotion:
# - The ranges of year since last promotion is 0 to 15 years
# - Most of the employee have not been promoted in last year
# - less than 300 employee have been promoted atleast 1 year.
#
# #### 23.Years With Current Manager:
# - Most employees have 2 years experience with current manager and
# - whereas less employees stay atleast 16 years with manager.
# - The range in between 0 to 17
# - less than 180 employee have 7 years experience with current manager.
#
# #### 24.Attrition:
# - Maximum no of employee does not leave the company
# - less than 200 employee have left the company
#
# #### 25. Performance Rating:
# - The range of performance rating is 2 to 4
# - most of the employees have performance rating 3
# - less number of employees performance rating is 4.
# - less than 200 employees has erformance rating 2.

# %% [markdown]
# #### 26.Employee Department

# %%
plt.figure(figsize=(10,5))
sns.countplot('EmpDepartment',data=data)
plt.xlabel('Employee Department',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation:
#
# - Fewer than 320 people work in the research and development department, which includes the majority of the sales staff.
# - Employees in the finance department and human resources are nearly equal.
# - The organization employs a minimum number of data science people

# %% [markdown]
# #### 27.Employee Job Role

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpJobRole',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=20)
plt.show()

# %% [markdown]
# #### Observation:
#
# - The maximum number of employees in the sales executive and developer job roles is 230.
# - The number of managers, R&D employees, and research scientists is fewer than 100; the number of employees in the other job roles is less than 65.

# %% [markdown]
# #### BIAVARIATE ANALYSIS
#
# In Bivariate analysis Checking the relation between two features
#
# #### ANALYSIS ON CONTINUOUS FEATURE
#
# PLOT USED:
# - Histogram, line plot used for continuous features
# - Count used for categorical & Discrete data.

# %% [markdown]
# #### 1.Relation Between age & Experience Years At This Company

# %%
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',data=data)
plt.xlabel('Age',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the age ranges from 18 to 25, the total number of years of experience is less than 5.
# - The total amount of experience likewise increases as age does.

# %% [markdown]
# #### 2.Relation Between experiance year at this company & total work experiance

# %%
sns.lineplot(x='ExperienceYearsAtThisCompany',y='TotalWorkExperienceInYears',data=data)
plt.xlabel('ExperienceYearsAtThisCompany',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - As the No. of years of experience at this company increases then total years of work experience also increases.

# %% [markdown]
# #### 3.Relation between Employee last salary hike and number of company worked

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='NumCompaniesWorked',data=data)
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# If the employee has worked in  1 or 2 companies then employee last salary hike percent is increases.

# %% [markdown]
# #### 4.Relation between Years Since Last Promotion and Experience Years In CurrentRole

# %%
sns.lineplot(x='YearsSinceLastPromotion',y='ExperienceYearsInCurrentRole',data=data)
plt.xlabel('YearsSinceLastPromotion',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - In above plot clearly seen that Number of Yeras since the last promotion increases with the experience with current role

# %% [markdown]
# #### 5.Relation between Employee Hourly Rate and Years With Current Manager

# %%
sns.lineplot(x='EmpHourlyRate',y='YearsWithCurrManager',data=data)
plt.xlabel('EmpHourlyRate',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# most of the employee hourly rate with their current manager is constant,but some of the employees has maximum hourly rate with less no of year with current manager.

# %% [markdown]
# #### 6.Relation between Distance From Home and Employee Last Salary Hike Percent

# %%
sns.lineplot(x='DistanceFromHome',y='EmpLastSalaryHikePercent',data=data)
plt.xlabel('DistanceFromHome',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the distance from home is more then the employee salary hike is slightly increases.
# - if the distance from home between 10 to 13 miles then employee salary hike is decreases.

# %% [markdown]
# #### ANALYSIS ON CATEGORICAL AND DISCERETE FEATURE
#
# #### CREATE A NEW DATAFRAME FOR CATEGORICAL FEATURES.

# %%
categorical = []  # Create empty list to store the feature
for column in data.columns:
    if data[column].dtype == object:
        categorical.append(column)
        print(f"{column} : {data[column].unique()}")
        print("====================================")
# Out:
# EmpNumber : ['E1001000' 'E1001006' 'E1001007' ... 'E100994' 'E100995' 'E100998']
# ...
# Gender : ['Male' 'Female']
# ...
# EducationBackground : ['Marketing' 'Life Sciences' 'Human Resources' 'Medical' 'Other'
#  'Technical Degree']
# ...
# MaritalStatus : ['Single' 'Married' 'Divorced']
# ...
# EmpDepartment : ['Sales' 'Human Resources' 'Development' 'Data Science'
#  'Research & Development' 'Finance']
# ...
# EmpJobRole : ['Sales Executive' 'Manager' 'Developer' 'Sales Representative'
#  'Human Resources' 'Senior Developer' 'Data Scientist'
#  'Senior Manager R&D' 'Laboratory Technician' 'Manufacturing Director'
#  'Research Scientist' 'Healthcare Representative' 'Research Director'
#  'Manager R&D' 'Finance Manager' 'Technical Architect' 'Business Analyst'
#  'Technical Lead' 'Delivery Manager']
# ...
# BusinessTravelFrequency : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ...
# OverTime : ['No' 'Yes']
# ...
# Attrition : ['No' 'Yes']
# ...

# %%
categorical
# Out:
# ['EmpNumber',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'OverTime',
#  'Attrition']

# %%
# Make a list of categorical feature and use sub plot to plot multiple feature
categorical_col = data[['Gender','EducationBackground','MaritalStatus','BusinessTravelFrequency','OverTime','Attrition']]
plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in categorical_col: # iteration of columns / acessing the columns from count 
    if plotno<=7:    # set the limit
        plt.subplot(3,2,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=categorical_col[column],hue=data.PerformanceRating) # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
        plt.ylabel('PerformanceRating')
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# #### Observations:
#
# #### 7. Relationship between Gender and performance rating
# - Maximum no of males have got performance rating as 3 as well as in females since they received performance rating 3.
# - male & female employees who received performance rating as 4 are less in number
#
# #### 8.Relationship between EducationBackground and performance rating
# - More number of people belonging to life sciences and medical education background employees have got rated 3 as their performance rating
# - life science and medical education background employees got rated as 2 & 4 performance rating most of the times
#
# #### 9.Relationship between MaritalStatus and performance rating
# - Most of the employees in married status have got their performance rating as 3 same goes with single and divored
#
# #### 10.Relationship between Business Travel Frequency and performance rating
# - The emploees who travel rarely has got performance rating 3
# - Those employees who travel frequently this employee are also rated with 2, 3, and 4
#
# #### 11.Relationship between Overtime and performance rating
# - Maximum no of employee with no overtime are rated with 3 perfomance rating
# - Those employee who are doing overtime then 2 & 4 performance rating is constant.
#
# #### 12.Relationship between Attrition and performance rating
# - Most of the employees who received performance rating 3 are not leaving the company but there are few employees who leave company even though they received 2,3,4

# %% [markdown]
# #### 13.Relationship between employee department and performance rating

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpDepartment',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - Most of the Development, Sales, And Research and development employee department has 3 peformance rating
# - Data science department employee has low performance rating.
# - In sales & Research and development department employees receive performance rating 2 most of the time.

# %% [markdown]
# #### 14.Relationship between employee job role and performance rating

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpJobRole',hue=data.PerformanceRating,data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - Developers and sales executive job role employee performance rating is 3 most of the time.
# - In technical architecture and delivery manger job role employee not rated with 2 & 4 performance rating.
# - In sales excutive also less than 60 employee rated with 2 performance rating.
# - Remaining all job role employee has 3 performance rating most of the time.
#
# #### REATE NEW DATAFRMAE FOR NUMERICAL FEATURES:

# %%
numerical_col = []
for column in data.columns:
    if data[column].dtype == "int64":
        data[column].unique()   # for continuos features we use unique>=10
        numerical_col.append(column)

# %%
numerical_col  # All numerical features
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmpEducationLevel',
#  'EmpEnvironmentSatisfaction',
#  'EmpHourlyRate',
#  'EmpJobInvolvement',
#  'EmpJobLevel',
#  'EmpJobSatisfaction',
#  'NumCompaniesWorked',
#  'EmpLastSalaryHikePercent',
#  'EmpRelationshipSatisfaction',
#  'TotalWorkExperienceInYears',
#  'TrainingTimesLastYear',
#  'EmpWorkLifeBalance',
#  'ExperienceYearsAtThisCompany',
#  'ExperienceYearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'PerformanceRating']

# %%
numerical = data[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction',
                 'EmpWorkLifeBalance']]

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in numerical: # iteration of columns / acessing the columns from count 
    if plotno<=7:    # set the limit
        plt.subplot(3,2,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=numerical[column],hue=data.PerformanceRating) # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
        plt.ylabel('PerformanceRating')
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# #### Observations:
#
# #### 15. Relationship between EmpEducationLevel and performance rating
# - Those employee education level whose education level is 3,4 & 2 gets peformance rating as 3 most of the times
# - If the performance rating is 2 & 4 and considering all education level employees are less than 60.
#
# #### 16. Relationship between EmpEnvironmentSatisfaction and performance rating
# - There are Maximum no of employee with enviorment statifaction as 3 and 4 as well as who got 3 as their performance rating.
# - If the employee environment satisfaction is 1 & 2 then the maximum number of employees have 2 performace rating.
# - If the employee environment satisfaction increases then the performance rating 4 also increases.
#
# #### 17. Relationship between EmpJobInvolvement and performance rating
# - Those employees whose job involvement level is 2 & 3 then those employees have 3 performance rating.
# - Since job involvement is less these employees usually get 2 and 3.
#
# #### 18. Relationship between EmpJobLevel and performance rating
# - If the employee job level is 1,2 & 3 then there are more number of employees who has performance rating 3
# - In all job levels number of employees who has got 2 & 4 performance rating is less than 60.
#
# #### 19. Relationship between EmpJobSatisfaction and performance rating
# - More number of employees who have rated 4 & 3 as job satisfaction those employees have got 3 as their performance rating.
# - In all levels of job satisfaction the employees who has got 2 & 4 as their performance rating is less than 55.
#
# #### 21. Relationship between EmpWorkLifeBalance and performance rating
# - If the employee work life balance rating is 3 then we can see maximum no of employees having 3 performance rating.
# - If the work life balance is 1 then there are no one who got 4 as their performance rating.

# %% [markdown]
# #### MULTIVARIATE ANALYSIS
#
# Checking the relationship between two features with respect to target features
#
# #### PLOT USED:
#
# Line plot: A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value. Barplot: It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.

# %% [markdown]
# #### 1.Check the relationship between Age & Total work experiance with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',hue=data.PerformanceRating,data=data)
plt.xlabel('Age',fontsize=20)
plt.ylabel('TotalWorkExperienceInYears',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the age & total experience increases then employee performance rating is usually 4.
# - Low age and minimum year experience employees has 4 perfomace rating.
# - At the age of 50 and 30 years of experience employee have 2 performance rating.

# %% [markdown]
# #### 2.Check the relationship between Gender & Number Companies Worked with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Gender',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Gender',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the gender is male and no of companies work is increses then the performance rating is 2 & 4.
# - If the gender is female and she has worked in in less no companies then performance rating is 2.
# - 3 & 4 performance rating is received by a female if the no of compaines she worked is increases.
#
#
# #### 3.Check the relationship between MaritalStatus & EmpLastSalaryHikePercent with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='MaritalStatus',y='EmpLastSalaryHikePercent',hue=data.PerformanceRating,data=data)
plt.xlabel('MaritalStatus',fontsize=20)
plt.ylabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - In every category of maritial status, the hike is more when the performance rating is 4
# - If salary hike percentage in last year is less than 15 then performance rating is usually 2 & 3 in all the categories of marital status.
#
# #### 4.Check the relationship between BusinessTravelFrequency & EmpEnvironmentSatisfaction with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='BusinessTravelFrequency',y='EmpEnvironmentSatisfaction',hue=data.PerformanceRating,data=data)
plt.xlabel('BusinessTravelFrequency',fontsize=20)
plt.ylabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the employee enviornment satisfaction is high then performance rating is 3 & 4 in all classes of business travel frequency.
# - Low employee environment satisfaction has 2 performance rating in all business travel frequency.

# %% [markdown]
# #### 5.Check the relationship between Attrition & YearsWithCurrManager with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='YearsWithCurrManager',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('YearsWithCurrManager',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If the employees experience with current manager increases then performance rating is 2 and equal chances of employee to leave the company.
# - those employee perfomance rating is 4 and experience with current manager increases then most of the employees does not leave the company.

# %% [markdown]
# #### 6.Check the relationship between EducationBackground & ExperienceYearsInCurrentRole with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EducationBackground',y='ExperienceYearsInCurrentRole',hue=data.PerformanceRating,data=data)
plt.xlabel('EducationBackground',fontsize=20)
plt.ylabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - Marketing employee who has more years of experience usually gets performance rating 4
# - In all other education background with current role experience more than 5 then usually the performance rating of employee is 2.
# - Life sciences, Medical, technical degree and other education background employee who has less than 4 year of experience in current role then the performance rating is 3 & 4.
#
# #### 7.Check the relationship between OverTime & DistanceFromHome with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='OverTime',y='DistanceFromHome',hue=data.PerformanceRating,data=data)
plt.xlabel('OverTime',fontsize=20)
plt.ylabel('DistanceFromHome',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# The employee's performance rating is same whether they work extra or not as the employee's distance from home increases.
#
# #### 8.Check the relationship between EmpDepartment & TrainingTimesLastYear with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpDepartment',y='TrainingTimesLastYear',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('TrainingTimesLastYear',fontsize=15)
plt.show()

# %% [markdown]
# Observation:
#
# - We could see data science employees are usually attending the training the maximum amount of times as well as with performance rating 2
# - All the other employees belonging to different departments who are attending less than 3 have got performance rating almost the same

# %% [markdown]
# #### 10.Check the relationship between Attrition & NumCompaniesWorked with respect to target feature

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# #### Observation:
#
# - If employee number of companies worked is increases then most of the employees leave the company and their performance rating is 2
# - Those employee who have worked in less no of companies they do not leave the company and their performance rating is constant.

# %% [markdown]
# #### CONCLUSION
# There are some features are positively correlated with performance rating( Target variable)
#
# 1. Emp Environment Satisfaction
# 2. Emp Last Salary Hike Percent
# 3. Emp Work Life Balance
